# %%
from huggingface_hub import login
login(token="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")

# %%
from datasets import load_dataset
ds = load_dataset(
    "FlyRank/internship-warehouse",
    "fact_content_daily_performance",
    streaming=True,
    split="train",
    token="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" # ضيف السطر ده
)
# Out:
# Resolving data files:   0%|          | 0/18 [00:00<?, ?it/s]

# %%
import duckdb
con = duckdb.connect()
con.execute("CREATE SECRET (TYPE huggingface, TOKEN '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')")
rel = "hf://datasets/FlyRank/internship-warehouse"
con.sql(f"SELECT COUNT(*) FROM read_parquet('{rel}/fact_content_daily_performance/**/*.parquet')")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │     78835655 │
# └──────────────┘

# %%
con.sql(f"SELECT MIN(report_date), MAX(report_date) FROM read_parquet('{rel}/fact_content_daily_performance/**/*.parquet')")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌──────────────────┬──────────────────┐
# │ min(report_date) │ max(report_date) │
# │       date       │       date       │
# ├──────────────────┼──────────────────┤
# │ 2025-01-27       │ 2026-06-30       │
# └──────────────────┴──────────────────┘

# %%
con.sql(f"SELECT COUNT(*) - COUNT(report_date) AS missing_date, COUNT(*) - COUNT(sessions_organic) AS missing_organic FROM read_parquet('{rel}/fact_content_daily_performance/**/*.parquet')")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌──────────────┬─────────────────┐
# │ missing_date │ missing_organic │
# │    int64     │      int64      │
# ├──────────────┼─────────────────┤
# │            0 │        29635327 │
# └──────────────┴─────────────────┘

# %%
con.sql(f"SELECT COUNT(*) AS total_rows, COUNT(DISTINCT report_date) AS unique_days FROM read_parquet('{rel}/fact_content_daily_performance/**/*.parquet')")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌────────────┬─────────────┐
# │ total_rows │ unique_days │
# │   int64    │    int64    │
# ├────────────┼─────────────┤
# │   78835655 │         520 │
# └────────────┴─────────────┘
